# %% [markdown]
# # Motivation of Learning (Contd.)
#
# ## ✅ **Expectancy Theory of Motivation (Recap & Details)**
#
# Motivation is influenced by the **expectation** that effort → performance → reward.
# We make internal judgments before deciding to pursue a goal.
#
# ### Factors considered:
#
# * **Past experience**
# * **Self-confidence in ability**
# * **Perceived difficulty of the task**
# * **Control over overcoming challenges**
#
# ### Core Components:
#
# | Component           | Meaning                                  | Key Questions                              |
# | ------------------- | ---------------------------------------- | ------------------------------------------ |
# | **Expectancy**      | Belief that effort leads to performance  | “Can I do this if I work hard?”            |
# | **Instrumentality** | Belief that performance will be rewarded | “Will my performance be fairly evaluated?” |
# | **Valence**         | Perceived value of the reward            | “Do I really want this reward?”            |
#
# ### Instrumentality Influences:
#
# * Reward criteria transparency
# * Performance appraisal system fairness
# * Preparedness for the task
# * Difficulty level vs skill match
#
# ### Valence Outcomes:
#
# * Can be **positive**, **neutral**, or **negative**
# * Depends on personal priorities and trade-offs
#   (e.g., promotion vs work-life balance)
#
# ---
#
# ## 🎯 **Goal Setting Theory (Edwin Locke)**
#
# Motivation increases when **clear and meaningful goals** are set.
#
# ### Effective Goal Characteristics:
#
# 1. **Clarity**
#    Goals must be specific, not vague or overly broad.
# 2. **Challenge**
#    Slight difficulty increases effort and engagement.
# 3. **Attainability**
#    Ambitious but achievable goals prevent frustration.
# 4. **Acceptance**
#    Self-chosen goals yield stronger motivation than imposed goals.
# 5. **Feedback**
#    Continuous feedback ensures correct progress.
# 6. **Performance-Focused**
#    Goals should improve performance, not just image.
# 7. **Deadlines**
#    Increase accountability and timely effort.
#
# ---
#
# ## 🧠 **Learning Goals vs Performance Goals**
#
# | Learning Goal Orientation                | Performance Goal Orientation      |
# | ---------------------------------------- | --------------------------------- |
# | Focus on learning, mastery, skill growth | Focus on results, rewards, grades |
# | Higher intrinsic motivation              | More extrinsic motivation         |
# | Promotes innovation & resilience         | May cause anxiety during failures |
#
# ---
#
# ## 🤝 Group vs Individual Goals
#
# * **Individual goals** create personal accountability
# * **Group goals** encourage collaboration, team identity
# * Both should be aligned for effective achievement
#
# ---
#
# ## ⭐ SMART Goals Framework
#
# **S.M.A.R.T stands for:**
#
# | Letter | Meaning    |
# | ------ | ---------- |
# | **S**  | Specific   |
# | **M**  | Measurable |
# | **A**  | Assignable |
# | **R**  | Realistic  |
# | **T**  | Time-bound |
#
# Used widely in:
#
# * Workplaces (project management)
# * Education (lesson objectives)
# * Personal development (career planning)
#
# ---
#
# ## ⚙️ Application in Learning & Work
#
# ### Why goals improve performance:
#
# * Activate advanced cognitive processes
#
#   * Reflective thinking
#   * Creative thinking
#   * Critical thinking
# * Build **self-efficacy** through successful progress
# * Maintain focus, discipline, and commitment
#
# ### Breaking Down Complexity:
#
# Large goals → **smaller subgoals**
# Helps manage:
#
# * Task difficulty
# * Multidisciplinary components
# * Stress and resource planning
#
# ---
#
# ## 📌 Goal Setting Model Summary
#
# ### Core Properties:
#
# * Specificity
# * Challenge
#
# ### Moderators:
#
# * Ability
# * Feedback
# * Commitment
# * Situational resources
# * Self-efficacy
# * Task complexity
#
# ### Mediators:
#
# * Effort
# * Choices
# * Persistence
# * Strategies
#
# → Leads to **Improved Performance & Goal Achievement**
#
# ---
#
# ## 🔍 Motivation Theories Covered So Far
#
# * **Drive Theory**
# * **Arousal Theory**
# * **Expectancy Theory**
# * **Goal Setting Theory**
