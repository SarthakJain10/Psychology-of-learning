# %% [markdown]
# # Memory and Cognition
#
# ## 🌟 What is Memory?
#
# Memory is a **psychological process** that enables us to:
#
# 1. **Acquire** information
# 2. **Store** information
# 3. **Retain** information
# 4. **Retrieve** information when needed
#
# We constantly rely on memory to bring past learning into present situations.
# Example: Preparing for and writing exams.
#
# ---
#
# ## 🎯 Goals of Human Memory
#
# Memory involves:
#
# * Preserving information for future use
# * Recovering stored information when required
#
# We forget irrelevant or unused information naturally.
#
# ---
#
# ## 🧬 Memory and the Brain
#
# Cognitive neuroscientists explain memory through **neural network changes**:
#
# * Learning creates **new neural connections**
# * Related neurons form **patterns or networks**
# * Practice strengthens these synaptic connections
# * Without rehearsal, memories fade
#
# Learning and memory both involve **restructuring brain circuits**.
#
# ---
#
# ## 🔄 Memory Processing Stages
#
# Memory works through **three major processes**:
#
# ### 1️⃣ Encoding
#
# * Receiving and processing information
# * Organizing input using logic, grouping, heuristics
#
# ### 2️⃣ Storage
#
# * Creating permanent records in:
#
#   * **Short-Term Memory (STM)**
#   * **Long-Term Memory (LTM)**
#
# ### 3️⃣ Retrieval
#
# * Recalling stored information when needed
# * Retrieval cues help us remember better
#   (like color-coding, notes, keywords)
#
# > Retrieval helps us evaluate whether learning was successful.
#
# ---
#
# ## 🧩 Role of Rehearsal & Mnemonics
#
# * Reviewing, practicing, summarizing improves encoding
# * Helps retain information long-term
# * Strengthens synaptic links
# * Techniques include:
#
#   * Chunking
#   * Visual cues
#   * Color coding
#   * Repeated revision
#
# Mnemonic strategies are memory boosters.
#
# ---
#
# ## ⚙ Information Processing Approach
#
# Memory explained as a **computer-like system**:
#
# | Human Cognition | Computer        |
# | --------------- | --------------- |
# | Encoding        | Input           |
# | Storage         | File saving     |
# | Retrieval       | Accessing files |
#
# Key assumptions:
#
# * Information processed **step-by-step**
# * Limited capacity per stage
#   (e.g., attention span ≈ 5 ± 2 items)
# * Processes are interactive
# * Used in **all** activities like thinking, problem-solving, writing, imagining
#
# Basic model:
#
# > **Environmental Stimuli → Sensory Register → Short-Term Memory → Long-Term Memory → Retrieval**
#
# ---
#
# ## 🧠 What is Cognition?
#
# Cognition covers **all mental activities** such as:
#
# * Attention
# * Perception
# * Memory
# * Learning
# * Thinking and reasoning
# * Decision making
# * Problem solving
# * Language usage
#
# It is the **umbrella concept** for all brain-based information processing.
#
# ---
#
# ## 🧑‍🤝‍🧑 Social Cognition
#
# Knowing:
#
# * Others' emotions and attitudes
# * Social expectations
# * Group behavior
# * Collective consciousness
#
# Helps build **relationships, cooperation, teamwork**, and successful social functioning.
#
# ---
#
# ## 📌 Summary
#
# Memory and cognition are interconnected:
#
# * Cognition includes **memory** as one component
# * Memory enables learning continuity
# * Neural and information-processing perspectives explain how we remember, store, and use knowledge
