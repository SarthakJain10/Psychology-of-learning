# %% [markdown]
# # 🧠 Memory Information Processing Model
#
# ### Atkinson & Shiffrin Model
#
# Memory involves three major stages:
#
# 1. **Encoding**
# 2. **Storage**
# 3. **Retrieval**
#
# Information flow:
#
# ```
# Environment → Sensory Memory → Short-Term/Working Memory → Long-Term Memory
#                                        ↑                       ↓
#                                    Retrieval ↔ Rehearsal
# ```
#
# Memory processing is **bidirectional**. Working memory retrieves stored information from LTM while solving tasks.
#
# ---
#
# ## 🧩 Working Memory (Short-Term Memory)
#
# | Feature          | Description                                        |
# | ---------------- | -------------------------------------------------- |
# | Role             | Temporary workspace while actively processing info |
# | Capacity         | **7 ± 2** items (Miller's law)                     |
# | Duration         | 20–30 seconds                                      |
# | Functions        | Rehearsal, analysis, problem-solving               |
# | Loss occurs when | No rehearsal or improper encoding                  |
#
# Working memory exists **until the task is completed**.
#
# ---
#
# ## 🎧 Sensory Memory / Sensory Registers
#
# | Sense input                             | Nature           |
# | --------------------------------------- | ---------------- |
# | Visual, auditory, tactile, smell, taste | Raw sensory data |
#
# * **Huge capacity**, extremely **short duration (1–3 sec)**
# * Recognition based on existing memory cues
# * **Attention acts as a filter** determining what moves forward
#
# Selective attention is guided by prior knowledge stored in **long-term memory**.
#
# ---
#
# ## 🔁 Types of Rehearsal
#
# ### 1️⃣ Maintenance (Rote) Rehearsal
#
# * Simple repetition
# * Keeps information in STM briefly
# * **No impact** on long-term storage
#
# ### 2️⃣ Elaborative Rehearsal
#
# * Connects new info with existing knowledge
# * Meaningful learning
# * Essential for **encoding → Long-Term Memory**
#
# Strategies:
#
# * Chunking
# * Mnemonics
# * Concept maps
# * Dual coding (visual + auditory)
# * Imagery
#
# ---
#
# ## 📦 Long-Term Memory (LTM)
#
# | Feature        | Description                             |
# | -------------- | --------------------------------------- |
# | Capacity       | Virtually **unlimited**                 |
# | Duration       | Permanent / relatively permanent        |
# | Storage format | Conceptual form: **Schemas (Schemata)** |
#
# New information is **assimilated** into interlinked knowledge networks.
#
# ---
#
# ## ❌ Forgetting
#
# Occurs due to:
#
# * Encoding failure
# * Retrieval failure
# * Interference of new/old info
# * **Decay** (lack of use)
# * Brain damage
#
# Most forgetting happens within **4 weeks** if no rehearsal follows learning.
#
# Greater forgetting:
#
# * When subject matter is **unfamiliar**
# * When learning is **surface-level**
#
# ---
#
# ## 🎓 Educational Implications
#
# To improve memory and learning:
#
# * Encourage **active rehearsal**
# * Use meaningful organization and chunking
# * Promote engagement through:
#
#   * Group work
#   * Discussion & debate
#   * Concept mapping
#   * Real-life connections
# * Focus on higher order thinking:
#
#   * Problem-solving
#   * Metacognition
#   * Reflection
#
# Better engagement = Better retention ✅
#
# ---
#
# ## 🧠 Functional Memory System Overview
#
# | Level            | Processes                                                      |
# | ---------------- | -------------------------------------------------------------- |
# | Executive        | Problem solving, metacognition                                 |
# | Control          | Attention, recognition, chunking, meaningfulness, organization |
# | Memory Structure | Sensory Register → Encoding → STM → Encoding → LTM → Retrieval |
